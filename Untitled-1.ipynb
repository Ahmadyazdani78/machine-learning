# %%
# !hostname
# !whoami
# Out:
# DESKTOP-0IU8A2N
# desktop-0iu8a2n\ahmad

# %%
import sys
from datetime import datetime
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
print(datetime.now(), time.localtime().tm_zone, 'UTC')
# Out:
# 2021-11-18 03:35:26.101996 Pacific Standard Time UTC

# %%
sys.version
# Out:
# '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]'

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': 0.3*np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j**0.8157678

print("\n-> Execution time was %s seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0 -1.081938  0.010426  0.786532  0.318834
# 1  0.227200 -1.346481 -0.256653 -0.542630
# 2 -0.913301  0.188973 -1.151399  1.103153
# 3  1.900169 -0.844899  1.152116 -1.318828
# 4 -1.335679 -0.281067  1.350441 -1.527064
# 5  0.339715 -0.775829  0.932928  1.239727
# 6 -1.780058 -1.684315  0.871979 -0.721217
# 7 -0.115048 -0.051291 -0.033562  0.710955
# 8  0.178281 -0.192296  0.597787 -0.206552
# 9 -0.839046  0.964851  0.560728 -0.062673
#
# -> Execution time was 24.967969179153442 seconds <-
